# %% [markdown]
# ## Question 1.1
#
# ### What is Python and why is it so widely used in data analysis?
#
# Python is a high-level programming language that is easy to read and write. It is widely used in data analysis because it provides powerful libraries such as pandas, NumPy, and matplotlib, which help in handling, analysing, and visualising data efficiently.
#
# ### Name at least four other fields (outside of data) where Python is commonly used, and give a one-sentence example of how it is used in each.
#
# - web development: used with frameworks like Django and Flask
# - automation: used to automate repetitive tasks
# - game development: used to build simple games
# - cybersecurity: used for penetration testing and security tools

# %%
print("Hello, DataTrove! My placement starts today.")
# Out:
# Hello, DataTrove! My placement starts today.

# %%
# ## Write a program that
#1. Asks the user to enter their name using `input()
#2. Asks the user to enter their job title
#3. Prints a welcome message in the given format

name = input("Enter your name: ")
job_title = input("Enter your job title: ")

print(f"Welcome, {name}! Your role is: {job_title}. Let's get to work.")
# Out:
# Welcome, Victory Nnamani! Your role is: Data Science Student. Let's get to work.

# %%
# ##"Write a program that asks the user for two numbers and prints:\n",
#Their sum,
# Their difference,
# Their product,
# Their result when divided (to 2 decimal places)
# Format each result clearly with a label


num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

print("Sum:", num1 + num2)
print("Difference:", num1 - num2)
print("Product:", num1 * num2)
print("Division:", format(num1 / num2, ".2f"))
# Out:
# Sum: 15.0
# Difference: 5.0
# Product: 50.0
# Division: 2.00

# %% [markdown]
# ## Question 1.5
#
# What is the difference between `print(name)` and `name` when typed in a Jupyter Notebook cell? When would each be more useful?
#
# ### Answer:
#
# In a Jupyter Notebook, typing `name` on its own will display the value of the variable only if it is the last line in the cell. This is because Jupyter automatically outputs the result of the final expression.
#
# On the other hand, `print(name)` explicitly displays the value of the variable regardless of where it appears in the code. It can be used multiple times within the same cell.
#
# `print(name)` is more useful when you want to display multiple outputs or format your results clearly. Simply typing `name` is more useful for quick inspection when working interactively.

# %% [markdown]
# ## Question 2.1
#
# Python has several core data types. For each one below, write a one-sentence description and create a variable storing an example value
#
# | Data Type | Description | Example variable name |
# |-----------|-------------|----------------------|
# | `int`     | A whole number without decimals | `units_sold` |
# | `float`   | A number with decimal points | `unit_price` |
# | `str`     | A sequence of characters (text) | `product_name` |
# | `bool`    | A value that is either True or False | `is_returned` |

# %%
## Fill in the descriptions above (double-click to edit), 
# then write the four variable assignments below

units_sold = 10
unit_price = 49.99
product_name = "Wireless Headphones"
is_returned = False

# %%
# ## Question 2.2
# Using the variables you created in 2.1, write code that:
# 1. Prints the **data type** of each variable using `type()`
# 2. Checks whether `unit_price` is greater than 50 and prints `True` or `False`
# 3. Converts `units_sold` to a float and prints the result


print(type(units_sold))
print(type(unit_price))
print(type(product_name))
print(type(is_returned))

print(unit_price > 50)

units_sold_float = float(units_sold)
print(units_sold_float)
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# False
# 10.0

# %%
# ## Question 2.3
# DataTrove processes thousands of sales transactions. 
# Imagine one transaction has the following details:
# Product: `\"Wireless Headphones\"`
# Region: `\"Delta State\"`
# Quantity sold: `3`
# Unit price: `49.99`
# Discount: `10` (percent)
# Write code that: 1. Stores each value in an appropriately named variable\n",
# 2. Calculates the **total amount after discount** and stores it in a variable called `total_amount`\n",
# 3. Prints a summary in the given format

product = "Wireless Headphones"
region = "Delta State"
quantity = 3
unit_price = 49.99
discount = 10

total_before_discount = quantity * unit_price
discount_amount = total_before_discount * (discount / 100)
total_amount = total_before_discount - discount_amount

print(f"Product: {product}")
print(f"Region: {region}")
print(f"Units: {quantity} x £{unit_price}")
print(f"Discount: {discount}%")
print(f"Total: £{format(total_amount, '.2f')}")
# Out:
# Product: Wireless Headphones
# Region: Delta State
# Units: 3 x £49.99
# Discount: 10%
# Total: £134.97

# %% [markdown]
# ### Question 2.4
#
# What happens if you try to add a `str` and an `int` together in Python? Write your answer below, then write a small code example that demonstrates the error — and then shows how to fix it.
#
# **Answer:**
#
# When you try to add a string (`str`) and an integer (`int`) in Python, it raises a `TypeError` because Python does not allow operations between different data types directly.
#
# To fix this, you need to convert one data type to match the other. The most common fix is converting the integer to a string using `str()`.

# %%
# This will cause an error
# print("Total: " + 10)

# Fixed version
print("Total: " + str(10))
# Out:
# Total: 10

# %% [markdown]
# ## Question 3.1
#
# Explain the difference between single quotes (`'`), double quotes (`"`), and triple quotes (`'''` or `"""`) in Python. When would you choose one over the others?
#
# **Answer:**
#
# Single quotes (' ') and double quotes (" ") are both used to define strings in Python, and they work the same way. You can choose either depending on convenience, especially if your string contains one type of quote inside it.
#
# Triple quotes (''' ''' or """ """) are used for multi-line strings or long text blocks. They are useful when writing paragraphs or documentation.
#
# In practice:
# - Use single or double quotes for short text
# - Use triple quotes for multi-line text

# %%
# ## Question 3.2
# The following string has been pulled from a messy dataset entry:\n",
# `python'
# "raw_entry = \"   electronics 
# Write code that:
# 1. Removes the leading and trailing whitespace
# "2. Converts it to **title case** (e.g. `\"Electronics\"`)
# 3. Checks whether the cleaned string is equal to `\"Electronics\"` 
# and prints `True` or `False`


raw_entry = "   electronics   "

# 1. Remove spaces
cleaned = raw_entry.strip()

# 2. Convert to title case
cleaned = cleaned.title()

# 3. Print cleaned result
print(cleaned)

# 4. Check if it equals "Electronics"
print(cleaned == "Electronics")
# Out:
# Electronics
# True

# %%
# ## Question 3.3
# A sales rep has been entered into the system as `\"j.morrison\"`. 
# Write code that: 
# 1. Splits the string on the `.` to get the initial and surname separately
# 2. Capitalises the first letter of each part\n",
# 3. Joins them back together with a full stop to produce `\"J.Morrison\"`\n",
# 4. Prints the result


name = "j.morrison"

parts = name.split(".")

first = parts[0].capitalize()
last = parts[1].capitalize()

result = first + "." + last

print(result)
# Out:
# J.Morrison

# %%
# ## Question 3.4
#Using the string `\"DataTrove Analytics — Turning Data into Decisions\"`:
# 1. Print the total length of the string\n",
# 2. Print the string reversed (using index slicing)\n",
# 3. Print only the word `\"DataTrove\"` using slicing\n",
# 4. Replace `\"Decisions\"` with `\"Action\"` 
# and print the result"


text = "DataTrove Analytics — Turning Data into Decisions"

# 1. Length of the string
print(len(text))

# 2. Reverse the string
print(text[::-1])

# 3. Extract "DataTrove"
print(text[:10])

# 4. Replace "Decisions" with "Action"
print(text.replace("Decisions", "Action"))
# Out:
# 49
# snoisiceD otni ataD gninruT — scitylanA evorTataD
# DataTrove
# DataTrove Analytics — Turning Data into Action

# %%
# ## Question 3.5
# Write a program that:
# 1. Asks the user to type a product category name (e.g. `\"ELECTRONICS\"` or `\"home & garden\"`)
# 2. Cleans it so it is in **title case** with no extra whitespace\n",
# 3. Checks whether the cleaned category is in this approved list:\n",
# "```python\n",
# approved = [\"Electronics\", \"Clothing\", \"Home & Garden\", \"Sports & Outdoors\",\n",
#  \"Food & Drink\", \"Beauty & Health\", \"Toys & Games\", \"Books & Stationery\"]\n",
# 4. Prints `\"Valid category: [name]\"` if it is in the list, or `\"Unknown category — please check\"` if not"


category = input("Enter product category: ")

cleaned = category.strip().title()

approved = ["Electronics", "Clothing", "Home & Garden", "Sports & Outdoors",
            "Food & Drink", "Beauty & Health", "Toys & Games", "Books & Stationery"]

if cleaned in approved:
    print(f"Valid category: {cleaned}")
else:
    print("Unknown category — please check")
# Out:
# Valid category: Electronics

# %% [markdown]
# ## Question 4.1
#
# What is the difference between `if`, `elif`, and `else`? Write a brief explanation and give a real-world data scenario where you would need all three.
#
# ### Answer:
#
# In Python, `if`, `elif`, and `else` are used to make decisions in code.
#
# - `if` is used to test a condition. If the condition is true, the code inside it runs.
# - `elif` means "else if" and is used to check another condition if the previous one was false.
# - `else` runs if none of the previous conditions are true.
#
# A real-world data example is classifying product prices. For instance, if a product is below £10, it is labelled as "Budget". If it is between £10 and £50, it is "Standard". If it is between £50 and £100, it is "Premium". Otherwise, it is "Luxury".

# %%
# ## Question 4.2
# "Write a program that:
# 1. Stores a `unit_price` value (you choose the number)\n",
# 2. Classifies it using these business rules:\n",
# - Under £10 → `\"Budget\"
# - £10 to £49.99 → `\"Standard\"
# - £50 to £99.99 → `\"Premium\"
# - £100 or more → `\"Luxury\"
# 3. Prints: `\"Price tier: [tier]\"`"


unit_price = 75  

if unit_price < 10:
    tier = "Budget"
elif unit_price < 50:
    tier = "Standard"
elif unit_price < 100:
    tier = "Premium"
else:
    tier = "Luxury"

print(f"Price tier: {tier}")
# Out:
# Price tier: Premium

# %%
# ## Question 4.3
# DataTrove flags certain orders for review. 
# Write a program that takes the following values and applies **all three** business rules using conditionals:
# python\
# quantity = 5\
# unit_price = 149.99\
# discount_pct = 20\
# return_flag = \"Y\"\



# Step 1: Define the values
quantity = 5
unit_price = 149.99
discount_pct = 20
return_flag = "Y"

# Step 2: Check conditions
flagged = False

if quantity > 4:
    print("FLAG: High quantity order")
    flagged = True

if unit_price * quantity > 500:
    print("FLAG: High value order")
    flagged = True

if return_flag == "Y":
    print("FLAG: Returned order")
    flagged = True

# Step 3: If nothing triggered
if not flagged:
    print("Order looks clean")
# Out:
# FLAG: High quantity order
# FLAG: High value order
# FLAG: Returned order

# %%
# ## Question 4.4 
# Write a program that asks the user to enter a **sales region** and checks:
# - If it is one of DataTrove's 10 active regions (Scotland, North East, North West, Yorkshire, Midlands, East Anglia, London, South East, South West, Wales), print `\"Active region\"`\n",
# - If it is a valid UK region but not in the list, print `\"Region not currently active\"`\n",
# - Otherwise print `\"Unrecognised region — check for typos\"`


active_regions = [
    "Scotland", "North East", "North West", "Yorkshire", "Midlands",
    "East Anglia", "London", "South East", "South West", "Wales"
]

region = input("Enter sales region: ")

# Clean the input
clean_region = region.strip().title()

# List of known UK regions (simplified for this task)
all_regions = active_regions + ["Northern Ireland"]

if clean_region in active_regions:
    print("Active region")
elif clean_region in all_regions:
    print("Region not currently active")
else:
    print("Unrecognised region — check for typos")
# Out:
# Active region

# %% [markdown]
# ## Question 5.1
#
# What is the difference between a `for` loop and a `while` loop? Give one example use case for each in a data analysis context.
#
# ### Answer:
#
# A `for` loop is used to iterate over a sequence (such as a list) and runs a fixed number of times based on the items in that sequence.
#
# A `while` loop runs as long as a condition remains true, and it is used when the number of iterations is not known in advance.
#
# In data analysis, a `for` loop can be used to go through a list of sales values and process each one. A `while` loop can be used to keep processing data until a certain condition is met, such as continuing to read transactions until no more records are left.

# %%
# ## Question 5.2
# Given this list of sales figures:
# `python
# sales = [1200, 450, 3800, 290, 5100, 620, 4400, 180, 2750, 990]\n",
# Write a `for` loop that:
# 1. Prints each sales figure
# 2. Also prints whether it is `\"Above target\"` (≥ £1000) or `\"Below target\"` (< £1000)"


# Step 1: Define the list
sales = [1200, 450, 3800, 290, 5100, 620, 4400, 180, 2750, 990]

# Step 2: Loop through the list
for sale in sales:
    print(sale)
    
    if sale >= 1000:
        print("Above target")
    else:
        print("Below target")
# Out:
# 1200
# Above target
# 450
# Below target
# 3800
# Above target
# 290
# Below target
# 5100
# Above target
# 620
# Below target
# 4400
# Above target
# 180
# Below target
# 2750
# Above target
# 990
# Below target

# %%
# ## Question 5.3
# Using the same `sales` list, write code (using a loop) that calculates and prints:
# 1. The **total** of all sales
# 2. The **average** sale value (to 2 decimal places)
# 3. The **highest** value
# 4. The **lowest** value
# *Do not use Python's built-in `sum()`, `max()`, or `min()` functions — calculate these manually using the loop.*"


# Step 1: Define the list
sales = [1200, 450, 3800, 290, 5100, 620, 4400, 180, 2750, 990]

# Step 2: Initialise variables
total = 0
highest = sales[0]
lowest = sales[0]

# Step 3: Loop
for sale in sales:
    total += sale
    
    if sale > highest:
        highest = sale
        
    if sale < lowest:
        lowest = sale

# Step 4: Calculate average
average = total / len(sales)

# Step 5: Print results
print("Total:", total)
print("Average:", round(average, 2))
print("Highest:", highest)
print("Lowest:", lowest)
# Out:
# Total: 19780
# Average: 1978.0
# Highest: 5100
# Lowest: 180

# %%
# ## Question 5.4
# The DataTrove team needs to clean a list of region names that came from a form where users typed freely:
# python
# raw_regions = [\"london\", \"SCOTLAND\", \"  Yorkshire  \", \"midlands\",
# \"NORTH WEST\", \"wales  \", \"  east anglia\", \"South East\",
# \"north east\", \"  SOUTH WEST  \"]
# Write a `for` loop that:
# 1. Cleans each entry (strip whitespace, convert to title case)
# 2. Stores the cleaned names in a new list called `clean_regions`
# 3. Prints `clean_regions` when done
# *This is a preview of exactly what data cleaning looks like.*"


# Step 1: Define the raw data
raw_regions = ["london", "SCOTLAND", "  Yorkshire  ", "midlands",
               "NORTH WEST", "wales  ", "  east anglia", "South East",
               "north east", "  SOUTH WEST  "]

# Step 2: Create empty list
clean_regions = []

# Step 3: Clean each item
for region in raw_regions:
    cleaned = region.strip().title()
    clean_regions.append(cleaned)

# Step 4: Output
print(clean_regions)
# Out:
# ['London', 'Scotland', 'Yorkshire', 'Midlands', 'North West', 'Wales', 'East Anglia', 'South East', 'North East', 'South West']

# %%
# ## Question 5.5
# Write a `while` loop that:
# 1. Starts with a `balance` of `£1000`
# 2. Each iteration, deducts a random amount between £50 and £200 (use `import random` and `random.randint()`)
# 3. Prints the balance after each deduction
# 4. Stops when the balance drops below £0
# 5. Prints `\"Account exhausted after [n] transactions\"` when done"


# Step 1: Import module
import random

# Step 2: Set seed
random.seed(42)

# Step 3: Initialise variables
balance = 1000
count = 0

# Step 4: Loop until balance is gone
while balance >= 0:
    deduction = random.randint(50, 200)
    balance -= deduction
    count += 1
    
    print("Balance:", balance)

# Step 5: Final output
print("Account exhausted after", count, "transactions")
# Out:
# Balance: 922
# Balance: 866
# Balance: 746
# Balance: 634
# Balance: 527
# Balance: 442
# Balance: 366
# Balance: 177
# Balance: 105
# Balance: -53
# Account exhausted after 10 transactions

# %% [markdown]
# ## Question 6.1
#
# What is a function in Python? What are the benefits of using functions instead of writing the same code multiple times? Give a data-related example.
#
# ### Answer:
#
# A function in Python is a reusable block of code that performs a specific task. It helps organise programs into smaller and more manageable parts.
#
# One major benefit of using functions is that they reduce repetition. Instead of writing the same code multiple times, a function allows you to write it once and reuse it whenever needed. This makes code cleaner, easier to understand, and easier to maintain. Functions also help in debugging because errors can be traced to a specific function.
#
# In data analysis, for example, a function can be created to clean text data by removing extra spaces and converting all text to lowercase. This function can then be applied to many rows of data instead of rewriting the cleaning steps repeatedly.

# %%
#Question 6.2
# "Write a function called `calculate_total` that:
# - Takes three parameters: `unit_price`, `quantity`, and `discount_pct`
# - Calculates the total after discount
# - Returns the result rounded to 2 decimal places
# Test it with at least three different sets of values and print the results."


def calculate_total(unit_price, quantity, discount_pct):
    total = unit_price * quantity
    discount = total * (discount_pct / 100)
    final_total = total - discount
    return round(final_total, 2)

# Test your function
print(calculate_total(50, 2, 10))
print(calculate_total(100, 5, 20))
print(calculate_total(49.99, 3, 10))
# Out:
# 90.0
# 400.0
# 134.97

# %%
#Question 6.3
#  Write a function called `classify_price` that:
# - Takes one parameter: `unit_price`
# - Returns the price tier as a string using the same rules as Question 4.2:
# - Under £10 → `\"Budget\"`
# - £10–£49.99 → `\"Standard\"`
# - £50–£99.99 → `\"Premium\"`
# - £100+ → `\"Luxury\"`
# Then write a loop that runs the function on each price in this list and prints the price and its tier:
# python
# prices = [4.99, 12.99, 34.99, 49.99, 74.99, 129.99, 9.99, 54.99]


def classify_price(unit_price):
    if unit_price < 10:
        return "Budget"
    elif unit_price < 50:
        return "Standard"
    elif unit_price < 100:
        return "Premium"
    else:
        return "Luxury"

prices = [4.99, 12.99, 34.99, 49.99, 74.99, 129.99, 9.99, 54.99]

for price in prices:
    print(price, "-", classify_price(price))
# Out:
# 4.99 - Budget
# 12.99 - Standard
# 34.99 - Standard
# 49.99 - Standard
# 74.99 - Premium
# 129.99 - Luxury
# 9.99 - Budget
# 54.99 - Premium

# %%
#Question 6.4
# Write a function called `count_vowels` that:
# - Takes a string as input
# - Returns how many vowels (a, e, i, o, u — upper and lower case) are in the string
# - Test it on: `\"DataTrove Analytics\"` and print the result as:
# `\"There are [n] vowels in 'DataTrove Analytics'\"`"


def count_vowels(text):
    vowels = "aeiouAEIOU"
    count = 0

    for char in text:
        if char in vowels:
            count += 1

    return count

result = count_vowels("DataTrove Analytics")
print("There are", result, "vowels in 'DataTrove Analytics'")
# Out:
# There are 7 vowels in 'DataTrove Analytics'

# %%
#Question 6.5
#  Write a function called `validate_order` that takes a dictionary representing one sales order:
# python
# order = {\"order_id\": \"DT-20240001\", \"product_name\": \"Wireless Headphones\", 
# \"quantity\": 3, \"unit_price\": 49.99, \"discount_pct\": 10,
# \"region\": \"Lagos\", \"return_flag\": \"N\",
#The function should check **all** of the following rules and return a list of any issues found:
# - `quantity` must be greater than 0
# - `unit_price` must be greater than 0
# - `discount_pct` must be between 0 and 100
# - `region` must be one of the 10 DataTrove regions
# - `return_flag` must be either `\"Y\"` or `\"N\"`
# If no issues are found, return `[\"Order is valid\"]`.
# Test it on the order above, and then test it on a broken order with at least two deliberate errors."



def validate_order(order):
    issues = []
    valid_regions = ["North", "South", "East", "West"]

    if order["quantity"] <= 0:
        issues.append("Invalid quantity")

    if order["unit_price"] <= 0:
        issues.append("Invalid unit price")

    if order["discount_pct"] < 0 or order["discount_pct"] > 100:
        issues.append("Invalid discount percentage")

    if order["region"] not in valid_regions:
        issues.append("Invalid region")

    if order["return_flag"] not in ["Y", "N"]:
        issues.append("Invalid return flag")

    return issues


# Test with correct order
order1 = {
    "order_id": "DT-10001",
    "product_name": "Laptop",
    "quantity": 2,
    "unit_price": 500,
    "discount_pct": 10,
    "region": "North",
    "return_flag": "N"
}

print(validate_order(order1))


# Test with broken order
broken_order = {
    "order_id": "DT-00000",
    "product_name": "Phone",
    "quantity": 0,
    "unit_price": -10,
    "discount_pct": 150,
    "region": "Unknown",
    "return_flag": "X"
}

print(validate_order(broken_order))
# Out:
# []
# ['Invalid quantity', 'Invalid unit price', 'Invalid discount percentage', 'Invalid region', 'Invalid return flag']

# %% [markdown]
# ## Question 7.1
#
# What is the difference between `append()` and `extend()` in Python lists? Write your explanation and show a code example of each.
#
# ### Answer:
#
# The `append()` method adds a single element to the end of a list. If you append another list, it will be added as one item (a nested list).
#
# The `extend()` method adds each element of another list to the original list individually. It merges the two lists into one.
#
# Example:
#
# ```python
# # append example
# list1 = [1, 2, 3]
# list1.append([4, 5])
# print(list1)  # Output: [1, 2, 3, [4, 5]]
#
# # extend example
# list2 = [1, 2, 3]
# list2.extend([4, 5])
# print(list2)  # Output: [1, 2, 3, 4, 5]

# %%
#Question 7.2
#  You have been given a raw list of product categories from a data entry form:
# `python
# raw_categories = [\"electronics\", \"CLOTHING\", \"home & garden\", \"Electronics\",
# \"sports & outdoors\", \"CLOTHING\", \"food & drink\", \"electronics\",
# \"Beauty & Health\", \"toys & games\", \"books & stationery\", \"CLOTHING\"]
# Write code that: 1. Cleans each entry to title case
# 2. Removes **all duplicates** while keeping the original order
# 3. Sorts the final list alphabetically
# 4. Prints the cleaned, deduplicated, sorted list
# 5. Prints how many unique categories there are"
      ]


raw_categories = ["electronics", "CLOTHING", "home & garden", "Electronics",
                  "sports & outdoors", "CLOTHING", "food & drink", "electronics",
                  "Beauty & Health", "toys & games", "books & stationery", "CLOTHING"]

cleaned_categories = []

# Step 1 & 2: clean to title case and remove duplicates (preserve order)
for category in raw_categories:
    cleaned = category.strip().title()
    if cleaned not in cleaned_categories:
        cleaned_categories.append(cleaned)

# Step 3: sort alphabetically
cleaned_categories.sort()

# Step 4: print cleaned list
print("Cleaned categories:", cleaned_categories)

# Step 5: print number of unique categories
print("Number of unique categories:", len(cleaned_categories))
# Out:
# Cleaned categories: ['Beauty & Health', 'Books & Stationery', 'Clothing', 'Electronics', 'Food & Drink', 'Home & Garden', 'Sports & Outdoors', 'Toys & Games']
# Number of unique categories: 8

# %%
# ## Question 7.3
# This program creates an order log, collects 5 product names from the user,
# sorts them alphabetically, checks if "Laptop Stand" exists,
# replaces the item at index 1 with "Laptop Stand",
# and prints the final order log

order_log = []

# Collect 5 product names from the user
for i in range(5):
    item = input("Enter product name: ")
    order_log.append(item)

# Sort the list alphabetically
order_log.sort()

# Check if "Laptop Stand" is in the list
if "Laptop Stand" not in order_log:
    print("Laptop Stand not found in order log")

# Replace item at index 1
order_log[1] = "Laptop Stand"

# Print final list
print("Final order log:", order_log)
# Out:
# Laptop Stand not found in order log
# Final order log: ['adaptor', 'Laptop Stand', 'earphone', 'headphone', 'mouse']

# %%
# ## Question 7.4
# This code analyses a list of sales transactions by:
# 1. printing all Electronics transactions
# 2. calculating total revenue
# 3. finding the highest value transaction
# 4. counting how many transactions are over £50

transactions = [
    {"product": "Wireless Headphones", "category": "Electronics", "total": 134.97},
    {"product": "Yoga Mat",            "category": "Sports & Outdoors", "total": 27.99},
    {"product": "Smart Watch",         "category": "Electronics", "total": 259.98},
    {"product": "Throw Blanket",       "category": "Home & Garden", "total": 29.99},
    {"product": "Protein Powder",      "category": "Food & Drink", "total": 59.98},
    {"product": "Bluetooth Speaker",   "category": "Electronics", "total": 34.99},
    {"product": "Hiking Backpack",     "category": "Sports & Outdoors", "total": 129.98},
    {"product": "Face Moisturiser",    "category": "Beauty & Health", "total": 18.99},
]

# 1. Print Electronics transactions
print("Electronics transactions:")
for t in transactions:
    if t["category"] == "Electronics":
        print(t)

# 2. Calculate total revenue
total_revenue = 0
for t in transactions:
    total_revenue += t["total"]

print("Total revenue:", round(total_revenue, 2))

# 3. Find highest transaction
highest = transactions[0]
for t in transactions:
    if t["total"] > highest["total"]:
        highest = t

print("Highest transaction:", highest["product"], "-", highest["total"])

# 4. Count transactions above £50
count = 0
for t in transactions:
    if t["total"] > 50:
        count += 1

print("Transactions above £50:", count)
# Out:
# Electronics transactions:
# {'product': 'Wireless Headphones', 'category': 'Electronics', 'total': 134.97}
# {'product': 'Smart Watch', 'category': 'Electronics', 'total': 259.98}
# {'product': 'Bluetooth Speaker', 'category': 'Electronics', 'total': 34.99}
# Total revenue: 696.87
# Highest transaction: Smart Watch - 259.98
# Transactions above £50: 4
