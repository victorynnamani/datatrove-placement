# %%
print("Hello, Welcome to my Industrial Placement")
# Out:
# Hello, Welcome to my Industrial Placement

# %% [markdown]
# My name is Victory Nnamani.
#
# I am a data science student.
#
# I am doing this industrial placement to gain practical experience in data science.
#
# I hope to learn how to solve real-world problems using data.

# %% [markdown]
# **What is Data Science?**
#
# Data science is the process of using data to solve problems and make predictions.
#
# **What is Data Analysis?**
#
# Data analysis involves examining data to find useful insights.
#
# **What do data professionals do?**
# - collect data
# - clean data
# - analyse data
# - present insights
#
# **Tools commonly used:**
# - Python
# - Excel
# - SQL
# - Power BI
#
# **Why data roles are important:**
#
# They help organisations make informed decisions.

# %% [markdown]
# **What is Git?**
#
# Git is a version control system used to track changes in code.
#
# **What is GitHub?**
#
# GitHub is an online platform used to store and share code.
#
# **Basic Git commands:**
# - git add → prepares files
# - git commit → saves changes
# - git push → uploads files to GitHub
